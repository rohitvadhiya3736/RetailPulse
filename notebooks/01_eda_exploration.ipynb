# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))

from src.data.ingestion import DataIngestion
from src.data.cleaning import DataCleaner
from src.features.engineering import FeatureEngineer
from src.eda.exploratory import ExploratoryAnalysis

raw = DataIngestion().load()
clean = DataCleaner().clean(raw)
df = FeatureEngineer().transform(clean)
summary = ExploratoryAnalysis().run_full_eda(df)
summary
# Out:
# 2026-05-25 10:12:30,554 | INFO | src.data.ingestion | Loading raw data from /Users/onlymec/RetailPulse/data/raw/online_retail.csv
# 2026-05-25 10:12:31,291 | INFO | src.data.ingestion | Normalizing raw data columns: {'InvoiceNo': 'Invoice', 'UnitPrice': 'Price', 'CustomerID': 'Customer ID'}
# 2026-05-25 10:12:31,371 | INFO | src.data.ingestion | Loaded 541909 rows, 8 columns
# 2026-05-25 10:12:31,486 | INFO | src.data.cleaning | Starting data cleaning on 541909 rows
# 2026-05-25 10:12:32,057 | INFO | src.data.cleaning | Dropped 0 rows with missing critical fields
# 2026-05-25 10:12:32,888 | INFO | src.data.cleaning | Removed 11805 invalid quantity/price rows
# 2026-05-25 10:12:33,348 | INFO | src.data.cleaning | Removed 5246 duplicate rows
# 2026-05-25 10:12:33,358 | INFO | src.data.cleaning | Cleaning complete: 524858 rows remain
# 2026-05-25 10:12:33,382 | INFO | src.features.engineering | Engineering features for 524858 transactions
# 2026-05-25 10:12:36,432 | INFO | src.eda.exploratory | Running advanced EDA
# {'n_rows': 524858,
#  'n_customers': 4339,
#  'n_products': 3922,
#  'n_countries': 38,
#  'date_range': ['2010-12-01 08:26:00', '2011-12-09 12:50:00'],
#  'total_revenue': 9014205.284,
#  'avg_order_value': 451.6134911823647,
#  'churn_rate': 0.33302604286702003}
